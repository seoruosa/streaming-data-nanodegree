# %%
import json
import pandas as pd


FILEPATH = 'police-department-calls-for-service.json'
df = pd.read_json(FILEPATH)

# %%
df
# Out:
#                                  address     address_type  agency_id  \
# 0                 Geary Bl/divisadero St     Intersection          1
# 1                      100 Blk Howard St     Geo-Override          1
# 2                  3300 Block Of 20th Av  Common Location          1
# 3                  1900 Block Of 18th Av  Premise Address          1
# 4                 Sansome St/chestnut St     Intersection          1
# 5                  Haight St/fillmore St     Intersection          1
# 6                     Geary Bl/parker Av     Intersection          1
# 7                    Battery St/union St     Intersection          1
# 8                1500 Block Of Haight St  Common Location          1
# 9                        5th St/minna St     Intersection          1
# 10                     Front St/green St     Intersection          1
# 11              3100 Block Of Mission St  Common Location          1
# 12              3100 Block Of Mission St  Common Location          1
# ...
